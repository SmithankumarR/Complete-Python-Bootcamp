# %% [markdown]
# ## Deep Dive into Operators

# %% [markdown]
# ### Video Outline:
# 1. Introduction to Operators
# 2. Arithmetic Operators
#    - Addition
#    - Subtraction
#    - Multiplication
#    - Division
#    - Floor Division
#    - Modulus
#    - Exponentiation
# 3. Comparison Operators
#    - Equal to
#    - Not equal to
#    - Greater than
#    - Less than
#    - Greater than or equal to
#    - Less than or equal to
# 4. Logical Operators
#    - AND
#    - OR
#    - NOT
# 5. Practical Examples and Common Errors

# %%
## Arithmethic Operation

a=25
b =15

add_result=a+b  #addiiton
sub_result=a-b  #substraction 
mult_result=a*b #multiplication
div_result=a/b  #division
floor_div_result=a//b ## floor division
modulus_result=a%b #modulus operation
exponent_result=a**b ## Exponentiation


print("add_result:", add_result)
print("sub_result:", sub_result)
print("mult_result:", mult_result)
print("div_result:", div_result)
print("floor_div_result:", floor_div_result)
print("modulus_result:", modulus_result)
print("exponent_result:", exponent_result)
# Out:
# add_result: 40
# sub_result: 10
# mult_result: 375
# div_result: 1.6666666666666667
# floor_div_result: 1
# modulus_result: 10
# exponent_result: 931322574615478515625

# %%
10/5
# Out:
# 2.0

# %%
21/5
# Out:
# 4.2

# %% [markdown]
# ## Floor division = normal division + take the lowest integer (floor value).

# %%
21//5
# Out:
# 4

# %% [markdown]
# #### Comparison Operators

# %%
## Comparison Operators
## == Equal to
a=10
b=10

a==b
# Out:
# True

# %%
str1="Smithan"
str2="Smithan"

str1==str2
# Out:
# True

# %%
## Not Equal to !=
str1!=str2
# Out:
# False

# %%
str3="Smithan"
str4="smithan"

str3!=str4
# Out:
# True

# %%
# greater than >

num1=65
num2=55

num1>num2
# Out:
# True

# %%
## less than <

print("num1<num2:", num1<num2)
# Out:
# num1<num2: False

# %%
#greater than or equal to
number1=45
number2=45

print("number1>=number2:", number1>=number2)
# Out:
# number1>=number2: True

# %%
#less than or equal to
number1=44
number2=45

print(number1<=number2)
# Out:
# True

# %% [markdown]
# #### Logical Operators

# %%
## And ,Not,OR
X=True
Y=True

result =X and Y
print("Both X and Y are True:", result)
# Out:
# Both X and Y are True: True

# %%
X=False
Y=True

result =X and Y
print("Either X or Y is False:", result)
# Out:
# Either X or Y is False: False

# %%
## OR
X=False
Y=False

result =X or Y
print("either X or Y is True:", result)
# Out:
# either X or Y is True: False

# %%
# Not operator
X=False
not X
# Out:
# True

# %%
## Simple Calculator

# Simple calculator
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

# Performing arithmetic operations
addition = num1 + num2
subtraction = num1 - num2
multiplication = num1 * num2
division = num1 / num2
floor_division = num1 // num2
modulus = num1 % num2
exponentiation = num1 ** num2

# Displaying results
print("Addition:", addition)
print("Subtraction:", subtraction)
print("Multiplication:", multiplication)
print("Division:", division)
print("Floor Division:", floor_division)
print("Modulus:", modulus)
print("Exponentiation:", exponentiation)
# Out:
# Addition: 54.0
# Subtraction: 14.0
# Multiplication: 680.0
# Division: 1.7
# Floor Division: 1.0
# Modulus: 14.0
# Exponentiation: 4.261655511456885e+30
